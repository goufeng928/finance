# %%
# PY3_DB_Server_Client_POST_Sync_TABLE_Pull_JSON_Records.ipynb
# Create by GF 2025-11-24 19:11

# %%
import json
import sys
# ..................................................
import pandas
import requests
# ..................................................
import PY3_DB_Server_Client_POST_Sync_TABLE_Pull_JSON_Records

# %%
OBJ = PY3_DB_Server_Client_POST_Sync_TABLE_Pull_JSON_Records.PY3_DB_Server_Client_POST_Sync_TABLE_Pull_JSON_Records()

# %%
URL:str = "http://192.168.81.130/PHP5_DB_Server_POST_Sync_TABLE_Pull_JSON_Records.php"

# %%
res = OBJ.POST_for_PGSQL_Query_Rows_Number(URL = URL, SQL_Statement = "SELECT * FROM logs;")
res
# Out:
# [{'rows_num': '129'}]

# %%
res = OBJ.POST_for_PGSQL_Query_Datas(URL = URL, SQL_Statement = "SELECT * FROM logs;")
pandas.DataFrame(res)
# Out:
# [DEBUG] Processing -> Records Number: 129 (Block: 1/1)
#       id        time                   object   event  afct_num unit     memo
# 0      1  2025-07-02  tushare_api_cache_en_us  insert      5403  row  日数据/不复权
# 1      2  2025-07-03  tushare_api_cache_en_us  insert      5403  row  日数据/不复权
# 2      3  2025-07-04  tushare_api_cache_en_us  insert      5405  row  日数据/不复权
# 3      4  2025-07-07  tushare_api_cache_en_us  insert      5403  row  日数据/不复权
# 4      5  2025-07-08  tushare_api_cache_en_us  insert      5403  row  日数据/不复权
# ..   ...         ...                      ...     ...       ...  ...      ...
# 124  125  2025-10-16  tushare_api_cache_en_us  insert      5428  row  日数据/不复权
# 125  126  2025-10-17  tushare_api_cache_en_us  insert      5431  row  日数据/不复权
# 126  127  2025-10-14  tushare_api_cache_en_us  insert      5424  row  日数据/不复权
# 127  128  2025-10-13  tushare_api_cache_en_us  insert      5424  row  日数据/不复权
# ...
